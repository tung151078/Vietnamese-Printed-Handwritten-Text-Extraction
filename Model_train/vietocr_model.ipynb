# %% [markdown]
# # Introduction
# <p align="center">
# <img src="https://raw.githubusercontent.com/pbcquoc/vietocr/master/image/vietocr.jpg" width="512" height="512">
# </p>
# This notebook describe how you can use VietOcr to train OCR model

# %%
! pip install --quiet vietocr==0.3.2
# Out:
#      |████████████████████████████████| 59 kB 4.7 MB/s
#      |████████████████████████████████| 280 kB 22.9 MB/s
#      |████████████████████████████████| 948 kB 46.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   Building wheel for gdown (PEP 517) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.4.0 which is incompatible.

# %% [markdown]
# # Inference

# %%
import matplotlib.pyplot as plt
from PIL import Image
from vietocr.tool.predictor import Predictor
from vietocr.tool.config import Cfg

# %%
config = Cfg.load_config_from_name('vgg_transformer')

# %% [markdown]
# Change weights to your weights or using default weights from our pretrained model. Path can be url or local file

# %%
# config['weights'] = './weights/transformerocr.pth'
config['weights'] = 'https://drive.google.com/uc?id=13327Y1tz1ohsm5YZMyXVMPIOjoOA0OaA'
config['cnn']['pretrained']=False
config['device'] = 'cpu'
config['predictor']['beamsearch']=False

# %%
detector = Predictor(config)
# Out:
# Cached Downloading: /root/.cache/gdown/https-COLON--SLASH--SLASH-drive.google.com-SLASH-uc-QUESTION-id-EQUAL-13327Y1tz1ohsm5YZMyXVMPIOjoOA0OaA
# Downloading...
# From: https://drive.google.com/uc?id=13327Y1tz1ohsm5YZMyXVMPIOjoOA0OaA
# To: /root/.cache/gdown/tmpkfove__p/dl
# 100%|██████████| 152M/152M [00:01<00:00, 104MB/s]

# %%
! gdown --id 1uMVd6EBjY4Q0G2IkU5iMOQ34X0bysm0b
! unzip  -qq -o sample.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1uMVd6EBjY4Q0G2IkU5iMOQ34X0bysm0b
# To: /content/sample.zip
# 100% 306k/306k [00:00<00:00, 90.2MB/s]

# %%
! ls sample | shuf |head -n 5
# Out:
# 036183007715.jpeg
# 034097001515.jpeg
# deskewed-2019_09_17_046642_201909171706369_102.jpg
# deskewed-2019_08_28_tran_thi_thanh_2019082813444611_9.jpg
# 026200002854.jpeg

# %%
img = '/content/8.png'
img = Image.open(img)
plt.imshow(img)
s = detector.predict(img)
s
# Out:
# 'Hai tiểu ba tìn nam miổi ngăn đồng'

# %% [markdown]
# # Download sample dataset

# %%
! gdown https://drive.google.com/uc?id=19QU4VnKtgm3gf0Uw_N2QKSquW1SQ5JiE
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=19QU4VnKtgm3gf0Uw_N2QKSquW1SQ5JiE
# To: /content/data_line.zip
# 100% 61.2M/61.2M [00:00<00:00, 90.4MB/s]

# %%
! unzip -qq -o ./data_line.zip

# %% [markdown]
# # Train model

# %% [markdown]
# 1.   Load your config
# 2.   Train model using your dataset above

# %% [markdown]
# Load the default config, we adopt VGG for image feature extraction

# %%
from vietocr.tool.config import Cfg
from vietocr.model.trainer import Trainer

# %% [markdown]
# # Change the config
#
# * *data_root*: the folder save your all images
# * *train_annotation*: path to train annotation
# * *valid_annotation*: path to valid annotation
# * *print_every*: show train loss at every n steps
# * *valid_every*: show validation loss at every n steps
# * *iters*: number of iteration to train your model
# * *export*: export weights to folder that you can use for inference
# * *metrics*: number of sample in validation annotation you use for computing full_sequence_accuracy, for large dataset it will take too long, then you can reuduce this number

# %%
config = Cfg.load_config_from_name('vgg_transformer')

# %%
#config['vocab'] = 'aAàÀảẢãÃáÁạẠăĂằẰẳẲẵẴắẮặẶâÂầẦẩẨẫẪấẤậẬbBcCdDđĐeEèÈẻẺẽẼéÉẹẸêÊềỀểỂễỄếẾệỆfFgGhHiIìÌỉỈĩĨíÍịỊjJkKlLmMnNoOòÒỏỎõÕóÓọỌôÔồỒổỔỗỖốỐộỘơƠờỜởỞỡỠớỚợỢpPqQrRsStTuUùÙủỦũŨúÚụỤưƯừỪửỬữỮứỨựỰvVwWxXyYỳỲỷỶỹỸýÝỵỴzZ0123456789!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ '

dataset_params = {
    'name':'hw',
    'data_root':'./data_line/',
    'train_annotation':'train_line_annotation.txt',
    'valid_annotation':'test_line_annotation.txt'
}

params = {
         'print_every':200,
         'valid_every':15*200,
          'iters':10000,
          'checkpoint':'./checkpoint/transformerocr_checkpoint.pth',    
          'export':'./weights/transformerocr.pth',
          'metrics': 10000
         }

config['trainer'].update(params)
config['dataset'].update(dataset_params)
config['device'] = 'cuda:0'

# %% [markdown]
# you can change any of these params in this full list below

# %%
config
# Out:
# {'aug': {'image_aug': True, 'masked_language_model': True},
#  'backbone': 'vgg19_bn',
#  'cnn': {'hidden': 256,
#   'ks': [[2, 2], [2, 2], [2, 1], [2, 1], [1, 1]],
#   'pretrained': True,
#   'ss': [[2, 2], [2, 2], [2, 1], [2, 1], [1, 1]]},
#  'dataloader': {'num_workers': 3, 'pin_memory': True},
#  'dataset': {'data_root': './data_line/',
#   'image_height': 32,
#   'image_max_width': 512,
#   'image_min_width': 32,
#   'name': 'hw',
#   'train_annotation': 'train_line_annotation.txt',
#   'valid_annotation': 'test_line_annotation.txt'},
#  'device': 'cuda:0',
#  'optimizer': {'max_lr': 0.0003, 'pct_start': 0.1},
#  'predictor': {'beamsearch': False},
#  'pretrain': {'cached': '/tmp/tranformerorc.pth',
#   'id_or_url': '13327Y1tz1ohsm5YZMyXVMPIOjoOA0OaA',
#   'md5': 'af6b46e9295eb1c27ca90bddf8c8729a'},
#  'quiet': False,
#  'seq_modeling': 'transformer',
#  'trainer': {'batch_size': 32,
#   'checkpoint': './checkpoint/transformerocr_checkpoint.pth',
#   'export': './weights/transformerocr.pth',
#   'iters': 10000,
#   'log': './train.log',
#   'metrics': 10000,
#   'print_every': 200,
#   'valid_every': 3000},
#  'transformer': {'d_model': 256,
#   'dim_feedforward': 2048,
#   'max_seq_length': 1024,
#   'nhead': 8,
#   'num_decoder_layers': 6,
#   'num_encoder_layers': 6,
#   'pos_dropout': 0.1,
#   'trans_dropout': 0.1},
#  'vocab': 'aAàÀảẢãÃáÁạẠăĂằẰẳẲẵẴắẮặẶâÂầẦẩẨẫẪấẤậẬbBcCdDđĐeEèÈẻẺẽẼéÉẹẸêÊềỀểỂễỄếẾệỆfFgGhHiIìÌỉỈĩĨíÍịỊjJkKlLmMnNoOòÒỏỎõÕóÓọỌôÔồỒổỔỗỖốỐộỘơƠờỜởỞỡỠớỚợỢpPqQrRsStTuUùÙủỦũŨúÚụỤưƯừỪửỬữỮứỨựỰvVwWxXyYỳỲỷỶỹỸýÝỵỴzZ0123456789!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ ',
#  'weights': 'https://drive.google.com/uc?id=13327Y1tz1ohsm5YZMyXVMPIOjoOA0OaA'}

# %% [markdown]
# You should train model from our pretrained

# %%
trainer = Trainer(config, pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19_bn-c79401a0.pth" to /root/.cache/torch/hub/checkpoints/vgg19_bn-c79401a0.pth
#   0%|          | 0.00/548M [00:00<?, ?B/s]
# Cached Downloading: /tmp/tranformerorc.pth
# Downloading...
# From: https://drive.google.com/uc?id=13327Y1tz1ohsm5YZMyXVMPIOjoOA0OaA
# To: /root/.cache/gdown/tmp1djj3ro7/dl
# 100%|██████████| 152M/152M [00:00<00:00, 201MB/s]
# Computing MD5: /tmp/tranformerorc.pth
# MD5 matches: /tmp/tranformerorc.pth
# Create train_hw: 100%|████████████████████████████████████████| 5483/5483 [00:05<00:00, 1033.78it/s]
# Created dataset with 5482 samples
# train_hw build cluster: 100%|████████████████████████████████| 5482/5482 [00:00<00:00, 81416.55it/s]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Create valid_hw: 100%|████████████████████████████████████████| 1813/1813 [00:01<00:00, 1243.98it/s]
# Created dataset with 1812 samples
# valid_hw build cluster: 100%|████████████████████████████████| 1812/1812 [00:00<00:00, 84054.00it/s]

# %% [markdown]
# Save model configuration for inference, load_config_from_file

# %%
trainer.config.save('config.yml')

# %% [markdown]
# Visualize your dataset to check data augmentation is appropriate

# %%
trainer.visualize_dataset()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# Train now

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# iter: 000200 - train loss: 1.619 - lr: 3.96e-05 - load time: 1.39 - gpu time: 222.47
# iter: 000400 - train loss: 1.357 - lr: 1.12e-04 - load time: 0.67 - gpu time: 219.55
# iter: 000600 - train loss: 1.272 - lr: 2.01e-04 - load time: 0.81 - gpu time: 221.57
# iter: 000800 - train loss: 1.213 - lr: 2.73e-04 - load time: 1.43 - gpu time: 219.71
# iter: 001000 - train loss: 1.156 - lr: 3.00e-04 - load time: 0.68 - gpu time: 221.08
# iter: 001200 - train loss: 1.139 - lr: 3.00e-04 - load time: 0.66 - gpu time: 221.01
# iter: 001400 - train loss: 1.105 - lr: 2.99e-04 - load time: 1.35 - gpu time: 222.12
# iter: 001600 - train loss: 1.078 - lr: 2.97e-04 - load time: 0.66 - gpu time: 220.73
# iter: 001800 - train loss: 1.060 - lr: 2.94e-04 - load time: 0.79 - gpu time: 221.67
# iter: 002000 - train loss: 1.035 - lr: 2.91e-04 - load time: 0.82 - gpu time: 220.08
# iter: 002200 - train loss: 1.027 - lr: 2.87e-04 - load time: 1.45 - gpu time: 222.45
# iter: 002400 - train loss: 1.017 - lr: 2.82e-04 - load time: 0.71 - gpu time: 218.68
# iter: 002600 - train loss: 1.002 - lr: 2.77e-04 - load time: 0.68 - gpu time: 220.63
# iter: 002800 - train loss: 0.991 - lr: 2.71e-04 - load time: 1.54 - gpu time: 221.91
# iter: 003000 - train loss: 0.981 - lr: 2.65e-04 - load time: 0.75 - gpu time: 220.58
# iter: 003000 - valid loss: 0.902 - acc full seq: 0.0298 - acc per char: 0.5541
# iter: 003200 - train loss: 0.981 - lr: 2.58e-04 - load time: 0.72 - gpu time: 220.10
# iter: 003400 - train loss: 0.963 - lr: 2.50e-04 - load time: 1.45 - gpu time: 221.27
# iter: 003600 - train loss: 0.965 - lr: 2.42e-04 - load time: 0.62 - gpu time: 220.58
# iter: 003800 - train loss: 0.945 - lr: 2.34e-04 - load time: 0.72 - gpu time: 219.75
# iter: 004000 - train loss: 0.942 - lr: 2.25e-04 - load time: 0.74 - gpu time: 220.89
# iter: 004200 - train loss: 0.934 - lr: 2.16e-04 - load time: 1.28 - gpu time: 219.71
# iter: 004400 - train loss: 0.922 - lr: 2.06e-04 - load time: 0.76 - gpu time: 221.66
# iter: 004600 - train loss: 0.935 - lr: 1.96e-04 - load time: 0.80 - gpu time: 219.77
# iter: 004800 - train loss: 0.912 - lr: 1.86e-04 - load time: 1.44 - gpu time: 220.99
# iter: 005000 - train loss: 0.910 - lr: 1.76e-04 - load time: 0.65 - gpu time: 219.27
# iter: 005200 - train loss: 0.907 - lr: 1.66e-04 - load time: 0.69 - gpu time: 221.79
# iter: 005400 - train loss: 0.901 - lr: 1.55e-04 - load time: 1.47 - gpu time: 220.30
# iter: 005600 - train loss: 0.892 - lr: 1.45e-04 - load time: 0.76 - gpu time: 218.97
# iter: 005800 - train loss: 0.892 - lr: 1.34e-04 - load time: 0.73 - gpu time: 221.58
# iter: 006000 - train loss: 0.895 - lr: 1.24e-04 - load time: 0.79 - gpu time: 219.47
# iter: 006000 - valid loss: 0.849 - acc full seq: 0.0682 - acc per char: 0.6394
# iter: 006200 - train loss: 0.880 - lr: 1.14e-04 - load time: 1.46 - gpu time: 219.64
# iter: 006400 - train loss: 0.880 - lr: 1.04e-04 - load time: 0.89 - gpu time: 220.27
# iter: 006600 - train loss: 0.879 - lr: 9.38e-05 - load time: 0.80 - gpu time: 221.59
# iter: 006800 - train loss: 0.866 - lr: 8.42e-05 - load time: 1.50 - gpu time: 219.48
# iter: 007000 - train loss: 0.869 - lr: 7.50e-05 - load time: 0.63 - gpu time: 220.04
# iter: 007200 - train loss: 0.867 - lr: 6.61e-05 - load time: 0.68 - gpu time: 221.92
# iter: 007400 - train loss: 0.859 - lr: 5.76e-05 - load time: 1.40 - gpu time: 218.59
# iter: 007600 - train loss: 0.861 - lr: 4.96e-05 - load time: 0.66 - gpu time: 221.17
# iter: 007800 - train loss: 0.869 - lr: 4.21e-05 - load time: 0.71 - gpu time: 221.98
# iter: 008000 - train loss: 0.856 - lr: 3.51e-05 - load time: 0.77 - gpu time: 220.16
# iter: 008200 - train loss: 0.846 - lr: 2.86e-05 - load time: 1.46 - gpu time: 217.78
# iter: 008400 - train loss: 0.858 - lr: 2.28e-05 - load time: 0.74 - gpu time: 220.55
# iter: 008600 - train loss: 0.848 - lr: 1.75e-05 - load time: 0.82 - gpu time: 217.02
# iter: 008800 - train loss: 0.853 - lr: 1.29e-05 - load time: 1.51 - gpu time: 219.42
# iter: 009000 - train loss: 0.845 - lr: 9.03e-06 - load time: 0.69 - gpu time: 218.51
# iter: 009000 - valid loss: 0.835 - acc full seq: 0.0824 - acc per char: 0.6486
# iter: 009200 - train loss: 0.848 - lr: 5.80e-06 - load time: 0.74 - gpu time: 218.31
# iter: 009400 - train loss: 0.846 - lr: 3.27e-06 - load time: 1.34 - gpu time: 217.92
# iter: 009600 - train loss: 0.851 - lr: 1.45e-06 - load time: 0.72 - gpu time: 220.29
# iter: 009800 - train loss: 0.849 - lr: 3.63e-07 - load time: 0.81 - gpu time: 219.26
# iter: 010000 - train loss: 0.840 - lr: 1.21e-09 - load time: 0.71 - gpu time: 216.39

# %% [markdown]
# Visualize prediction from our trained model

# %%
trainer.visualize_prediction()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# Compute full seq accuracy for full valid dataset

# %%
trainer.precision()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# (0.09090909090909091, 0.6564938)

# %%
trainer.visualize_prediction()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
